# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('/content/Real_Estate_Sales_2001-2022_GL.csv', dtype=str)
df = df.replace('-', '', regex=True)
df.columns = df.columns.str.replace(' ', '_')
df.shape
# Out:
# (1097629, 14)

# %%
df.head(5)
# Out:
#   Serial_Number List_Year Date_Recorded     Town          Address  \
# 0       2020177      2020    04/14/2021  Ansonia    323 BEAVER ST
# 1       2020225      2020    05/26/2021  Ansonia   152 JACKSON ST
# 2       2020348      2020    09/13/2021  Ansonia  230 WAKELEE AVE
# 3       2020090      2020    12/14/2020  Ansonia      57 PLATT ST
# 4        210288      2021    06/20/2022     Avon   12 BYRON DRIVE
#
#   Assessed_Value Sale_Amount Sales_Ratio Property_Type Residential_Type  \
# 0      133000.00   248400.00      0.5354   Residential    Single Family
# 1      110500.00   239900.00      0.4606   Residential     Three Family
# 2      150500.00   325000.00       0.463    Commercial              NaN
# 3      127400.00   202500.00      0.6291   Residential       Two Family
# 4      179990.00   362500.00      0.4965   Residential            Condo
#
#   Non_Use_Code Assessor_Remarks OPM_remarks                           Location
# ...

# %%
df1 = df.drop([
    'Serial_Number', 'List_Year', 'Date_Recorded', 'Sales_Ratio', 'List_Year', 'OPM_remarks',
    'Location', 'Town', 'Assessed_Value', 'Sale_Amount', 'Non_Use_Code', 'Assessor_Remarks',
    ],axis='columns')
df1.head(3)
# Out:
#            Address Property_Type Residential_Type
# 0    323 BEAVER ST   Residential    Single Family
# 1   152 JACKSON ST   Residential     Three Family
# 2  230 WAKELEE AVE    Commercial              NaN

# %%
df1.dropna(subset=['Residential_Type', 'Address', 'Property_Type'], inplace=True)
df1.shape
# Out:
# (699236, 3)

# %%
df1.to_csv('test_coordinate.csv', index=False, encoding='utf-8', float_format='%.2f')
